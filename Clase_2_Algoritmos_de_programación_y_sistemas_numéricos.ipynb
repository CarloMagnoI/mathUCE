# %% [markdown]
# <a href="https://colab.research.google.com/github/CarloMagnoI/mathUCE/blob/main/Clase_2_Algoritmos_de_programaci%C3%B3n_y_sistemas_num%C3%A9ricos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clase 2: Algoritmos de programación y sistemas numéricos.**

# %% [markdown]
# ## 🤖 **Algoritmos y Sistemas Numéricos**

# %% [markdown]
# ### 💻 ***Algoritmos de Programación:***
#
# Los algoritmos de programación son conjuntos de reglas que indican al ordenador cómo ejecutar una tarea.
#
# - **Algoritmo en lenguaje común:** Conjunto de datos, pasos o procesos para llegar a un resultado (como hacer fideos, en lenguaje común).
# - **Algoritmo en lenguaje computacional:** Lenguaje que depende de si es interpretativo o de máquina, que una computadora usa para resolver un problema.

# %% [markdown]
# ### 🔄 ***Diagrama de Flujo:***
#
# Un diagrama de flujo representa la esquematización gráfica de un algoritmo, el cual muestra gráficamente los pasos o procesos a seguir para alcanzar la solución de un problema.

# %% [markdown]
# ### 👨‍💻***Algoritmo y diagrama de flujo***
#
# ![1000007088.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 💪 ***Ejercicio propuesto en clase sobre el área de un cuadrado***
#
# ![1000007084.jpg](data:image/jpeg;base64,...)![1000007085.jpg](data:image/jpeg;base64,...)![1000007086.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### *Codigo del area del cuadrado en Python*

# %%
def calcular_area_cuadrado(lado):
    area = lado ** 2
    return area

# Ejemplo de uso
lado = 5  # Longitud del lado del cuadrado
area = calcular_area_cuadrado(lado)
print(f"El área del cuadrado con lado {lado} es: {area}")
# Out:
# El área del cuadrado con lado 5 es: 25

# %% [markdown]
# ### 🔄 **E/P/S (Entrada/Proceso/Salida)**
#
# ## 📥 **Entrada:**
#
# La **entrada** es el conjunto de datos necesarios para realizar un cálculo y resolver un problema. Estos datos pueden ser proporcionados por el usuario, generados por otros sistemas, o leídos de archivos y bases de datos. La precisión y relevancia de los datos de entrada son cruciales para obtener resultados precisos.
#
# ### Ejemplos de Entrada:
#
# - Datos ingresados por el usuario en un formulario.
# - Valores de sensores en un sistema de monitoreo.
# - Información leída de un archivo CSV.
#
# ## ⚙️ **Proceso:**
#
# El **proceso** es el conjunto de operaciones y procedimientos que se aplican a los datos de entrada para transformarlos y resolver el problema planteado. Este paso incluye cálculos, evaluaciones de condiciones, bucles y cualquier otro tipo de manipulación de datos necesaria para producir la salida deseada.
#
# ### Ejemplos de Proceso:
#
# - Realizar cálculos matemáticos en una hoja de cálculo.
# - Aplicar un algoritmo de clasificación en un conjunto de datos.
# - Procesar imágenes para detectar objetos.
#
# ## 📤 **Salida:**
#
# La **salida** es el resultado del proceso, es decir, la resolución del problema. La salida puede ser en forma de datos visuales, archivos, mensajes, o cualquier otra forma que sea útil para el usuario o sistema que solicitó la operación. Es importante que la salida sea clara, precisa y útil para la toma de decisiones.
#
# ### Ejemplos de Salida:
#
# - Resultados mostrados en una interfaz de usuario.
# - Informes generados en formato PDF.
# - Señales enviadas a otros sistemas para tomar acciones.

# %% [markdown]
# ### ↘️ ***Imagen E/P/S***
#
# ![1000007089.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 🔎***¿Cómo Localizar Rápidamente un Número en una Lista Extensa?***
#
#    - *Búsqueda Lineal:* Encontrar un numero de uno en uno, es un proceso muy tardado.
#
# ![1000007090.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#    - *Búsqueda Binaria:* Encontrar un numero dividiendo la información a la mitad en cada pregunta.
#
#    ![1000007091.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 🎓 **Conclusiones**
#
# ## 📊 **Importancia del Ordenamiento**
#
# El ordenamiento es fundamental en el procesamiento de datos y algoritmos. Permite organizar la información de manera estructurada, facilitando búsquedas eficientes y operaciones más rápidas. Un buen ordenamiento mejora significativamente la capacidad de respuesta y la eficiencia de los sistemas informáticos.
#
# ## 🚀 **Eficiencia Comparativa**
#
# Comparar la eficiencia de diferentes algoritmos y sistemas numéricos es crucial para seleccionar la mejor solución en términos de tiempo y recursos. Algoritmos eficientes reducen el consumo de energía, el tiempo de ejecución y mejoran la experiencia del usuario.
#
# ## 🔍 **Aplicabilidad en Situaciones Reales**
#
# Los conceptos de algoritmos y sistemas numéricos tienen aplicaciones prácticas en diversas áreas, como la ciencia de datos, la ingeniería, la economía y más. Comprender y aplicar correctamente estos conceptos permite resolver problemas complejos de manera efectiva y tomar decisiones informadas basadas en datos.

# %% [markdown]
# ## 🔢 **Sistemas Numéricos**

# %% [markdown]
# ### **ℕ (Números Naturales):**
#
# - **Definición:** `{0, 1, 2, 3, ... , +∞}`
# - **Propiedades:**
#   - **(N, ≤):** Para todos \(a, b ∈ ℕ\), \(a \leq b\) o \(a > b\).
#   - **(N, +):** Para todos \(a, b ∈ ℕ\), existe un \(c ∈ ℕ\) tal que \(c = a + b\).

# %% [markdown]
# ### 🔄 **Extensión de ℕ a ℤ:**
#
# - **Problema de Simetización:** Resolver la operación de suma con el número cero.
#   - Ejemplo: \(n + ? = 0\)
#   - Solución: Aparece el concepto de números enteros, donde \(n + (-n) = 0\), resultando en los **Números Enteros (ℤ)**.
#
# ## **ℤ (Números Enteros):**
#
# - **Definición:** `{... , -3, -2, -1, 0, 1, 2, 3, ... , +∞}`

# %% [markdown]
# ### **Extensión de ℕ a ℚ:**
# **Operaciones Adicionales en ℕ:**
#   - **(N, <, +, ×):**
#   -  $ (a \cdot \ b = ?)$
#   - $(a \cdot ? = b)$
#   - Ejemplo: $5 \cdot ? = 50$
#     - Solución: $\(? = \frac{50}{5}\)$ resultando en los \${Números Racionales (ℚ)}$.
#
#   ## **ℚ (Números Racionales):**
#
# - **Definición:** $\frac{n}{m} ; n ∈ ℤ, m ∈ ℕ $

# %% [markdown]
# ### **Extensión de ℕ a ℝ:**
#
# - **Operaciones Adicionales:**
#   - **Resolución de Ecuaciones:**
#
#     - 2x = 10
#     -
# $(x⋅x=10)$
#   → $(x^2 = 10)$ →
#  $(3^2 < 10 < 4^2)$
#     -
# $(x^2 = 25)$ →
#  $(x_1 = -5)$, $(x_2 = 5)$
#     -
# $(x^2 + 1 = 0)$ →
#  $(x^2 = -1)$ → **Números Imaginarios (ℑ)**
#
#   ## **ℝ (Números Reales):**
#
# - **Definición:** Toda la recta numérica

# %% [markdown]
# ### **Relación entre Conjuntos Numéricos:**
#
# **Por ende,** \(ℕ ⊆ ℤ ⊆ ℚ ⊆ ℝ\)
