# %% [markdown]
# <a href="https://colab.research.google.com/github/CarloMagnoI/mathUCE/blob/main/Clase_5_Aplicaci%C3%B3n_a_la_Econom%C3%ADa_en_Funci%C3%B3n_Biyectiva_y_Compuesta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Clase 5: Aplicación a la Economía en Función Biyectiva y Compuesta.***

# %% [markdown]
# ## 🧠 ***Recordemos***

# %% [markdown]
# ### 📑 ***Conceptos de Funciones y su Aplicación en Economía***
#
# En este artículo, vamos a explorar los conceptos fundamentales de las funciones, su representación y su aplicación en el ámbito económico a través de las funciones de utilidad. Utilizaremos tanto los gráficos como las explicaciones detalladas para garantizar una comprensión profunda y clara.

# %% [markdown]
# #### 📚***Definición y Representación de Funciones***
#
# Una **función** es una regla de asociación que asigna a cada elemento de un conjunto de partida $( A )$ un elemento único en un conjunto de llegada $( B )$. La notación matemática estándar para una función es $( f: A \to B )$. Visualmente, podemos imaginar esto como un mapa que toma cada elemento $( x )$ en $( A )$ y lo asocia con un elemento $( f(x) )$ en $( B )$.
#
# Imaginemos que $( A )$ es un conjunto de números y $( B )$ es un conjunto de colores. La función $( f )$ podría representar una regla que asocia cada número con un color específico.

# %% [markdown]
# #### 📚***Imagen y Preimagen de una Función***
#
# Cuando hablamos de funciones, es crucial entender los conceptos de **imagen** y **preimagen**:
#
# - **Preimagen**: La preimagen de un conjunto en $( B )$ es el conjunto de todos los elementos en $( A )$ que se mapean a ese conjunto específico en $( B )$ bajo la función $( f )$. La preimagen de un elemento $( y )$ en $( B )$ se denota como $( f^{-1}(y) )$. $(Dominio)$.
# - **Imagen**: La imagen de un conjunto $( A )$ bajo una función $( f )$ es el conjunto de todos los valores que $( f(x) )$ puede tomar cuando $( x )$ varía en $( A )$. Matemáticamente, se denota como $( f(A) )$. $(Rango)$ y/o $(Recorrido)$.

# %% [markdown]
# ## 👩‍🔬 ***Funciones de Utilidad en Economía***
#
# En el ámbito económico, una **función de utilidad** es una herramienta que se utiliza para representar el nivel de satisfacción o bienestar de un individuo en relación con el consumo de bienes. Esta función toma como entrada la cantidad de bienes consumidos y produce como salida un valor que representa la utilidad o satisfacción obtenida.

# %% [markdown]
# - ##### 💭 ***Función de Utilidad con un Solo Bien***
#
# Consideremos un ejemplo simple en el que el único bien disponible es agua. La función de utilidad, en este caso, puede representarse como $( u(x) )$, donde $( x )$ es la cantidad de agua consumida y $( u(x) )$ es la utilidad obtenida.
#
# $[ \text{Agua} \, (x) \rightarrow \text{Utilidad} \, (u(x)) $]
#
# Gráficamente, podemos representar esta relación con una curva que muestra cómo la utilidad aumenta a medida que se consume más agua. Sin embargo, la utilidad marginalmente decrece, lo que significa que cada unidad adicional de agua proporciona una utilidad menor que la anterior. Por ejemplo, el primer vaso de agua puede proporcionar mucha satisfacción en un día caluroso, pero el tercer o cuarto vaso proporciona una satisfacción significativamente menor.

# %% [markdown]
# - ##### 💭 ***Funciones de Utilidad con Dos Bienes***
#
# La situación se vuelve más interesante cuando consideramos dos bienes, como agua y pan. Ahora, la función de utilidad depende de ambas cantidades consumidas:
#
# $[ u(x, y) ]$
#
# Aquí, $( x )$ es la cantidad de agua y $( y )$ es la cantidad de pan. La utilidad se representa en un gráfico tridimensional, donde los ejes $( x )$ e $( y )$ corresponden a las cantidades de los dos bienes, y el eje vertical representa la utilidad. Esta representación gráfica muestra una **superficie de utilidad**.
#
# Imaginemos una superficie en forma de concha acústica, donde cada punto en la superficie representa un nivel de utilidad específico asociado con una combinación particular de $( x )$ e $( y )$. Si solo miramos desde el lado de $( x )$ o $( y )$, veremos curvas similares a las que teníamos en el caso unidimensional.
#
# Ejemplos de funciones de utilidad que se ajustan a esta descripción incluyen:
#
# - $( \log(x) )$
# - $( \sqrt{x} )$
#
# Ambas funciones tienen la característica de ser crecientes pero con una pendiente cada vez menor, reflejando el principio de ***utilidad marginal decreciente.***

# %% [markdown]
# - ## 🔢 ***Notación Matemática de la Función de Utilidad***
#
# 1. **Definición de la Función de Utilidad**:
#    $[
#    U: \mathbb{R}^2_+ \rightarrow \mathbb{R}^+
#    ]$
#    Esta notación indica que la función de utilidad \( U \) toma como entrada un par de números reales no negativos $(( \mathbb{R}^2_+ ))$ y produce un número real no negativo $(( \mathbb{R}^+ ))$.
#
# 2. **Expresión de la Función de Utilidad**:
#    $[
#    (x, y) \rightarrow u(x, y)
#    ]$
#    Aquí, $( (x, y) )$ son las cantidades de dos bienes, y $( u(x, y) )$ es el nivel de utilidad asociado con esas cantidades.
#
# 3. **Conjuntos de Nivel**:
#    $[
#    \{ (x, y) \in \mathbb{R}^2_+ : u(x, y) = 10 \}
#    ]$
#    Esto representa el conjunto de todos los pares $((x, y))$ en $(\mathbb{R}^2_+)$ que producen una utilidad de 10. En el gráfico, estos conjuntos de nivel están representados por curvas de nivel $(isocuantas)$ en rojo

# %% [markdown]
# - ***Gráfica de la Función en Python***

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definimos la función de utilidad
def u(x, y):
    return np.log(x) + np.sqrt(y)

# Rango de valores para x e y
x = np.linspace(0.1, 5, 400)  # evitamos x=0 para evitar log(0)
y = np.linspace(0, 10, 400)
X, Y = np.meshgrid(x, y)
Z = u(X, Y)

# Creamos la figura
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Gráfico de la superficie de la función de utilidad
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.8)

# Contornos en el plano
contours = ax.contour(X, Y, Z, levels=[1, 2, 3, 4, 5, 10], cmap='autumn', linestyles="solid")

# Etiquetas y título
ax.set_xlabel('Bien X')
ax.set_ylabel('Bien Y')
ax.set_zlabel('Utilidad U(x, y)')
ax.set_title('Superficie de la Función de Utilidad y Conjuntos de Nivel')

# Mostrar el gráfico
plt.show()

# %% [markdown]
#  ***Continuación de la Función de Utilidad: Conjuntos de Nivel y Preimagen***
#
# **Notación Matemática**
#
# 1. **Conjuntos de Nivel**:
#
#    $[
#    f^{-1}(\{10\}) = \{ (x, y) \in \mathbb{R}^2_+ : u(x, y) \in \{10\} \}
#    ]$
#
#    Este conjunto representa todos los pares $((x, y))$ que producen una utilidad de 10. Esto se expresa de la siguiente manera:
#
#    $[
#    \{ (x, y) : \sqrt{xy} = 10 \}
#    ]$
#
#    Simplificando, obtenemos:
#
#    $[
#    \{ (x, y) : xy = 100 \}
#    ]$
#
#    O, de manera equivalente:
#
#    $[
#    \{ (x, y) : y = \frac{100}{x} \}
#    ]$
#
# 2. **Generalización para un Nivel de Utilidad $( u_0 )$**:
#
#    $[
#    f^{-1}(\{u_0\}) = \{ (x, y) \in \mathbb{R}^2_+ : y = \frac{u_0^2}{x} \}
#    ]$
#
#    Esto indica que, para un nivel de utilidad $( u_0 )$, la relación entre $( x )$ e $( y )$ se mantiene conforme a la ecuación mencionada.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definimos la función de utilidad
def u(x, y):
    return np.sqrt(x * y)

# Rango de valores para x e y
x = np.linspace(0.1, 10, 400)  # evitamos x=0 para evitar problemas de log(0)
y = np.linspace(0.1, 10, 400)
X, Y = np.meshgrid(x, y)
Z = u(X, Y)

# Valores de utilidad para los contornos
u_levels = [5, 10, 15, 20, 25]

# Creamos la figura
fig = plt.figure(figsize=(14, 9))
ax = fig.add_subplot(111, projection='3d')

# Gráfico de la superficie de la función de utilidad
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.7)

# Dibujamos los conjuntos de nivel
for u0 in u_levels:
    x_contour = np.linspace(0.1, 10, 400)
    y_contour = (u0**2) / x_contour
    z_contour = u(x_contour, y_contour)
    ax.plot(x_contour, y_contour, z_contour, label=f'u0 = {u0}', linewidth=2)

# Etiquetas y título
ax.set_xlabel('Bien X')
ax.set_ylabel('Bien Y')
ax.set_zlabel('Utilidad U(x, y)')
ax.set_title('Superficie de la Función de Utilidad y Conjuntos de Nivel')

# Mostrar leyenda y gráfico
ax.legend()
plt.show()

# %% [markdown]
# ***El gráfico en pocas plabras representa, la Utilidad Marginal Decreciente (beneficio de producir, consumir, etc, una unidad mas), y las Curvas de Indiferncia, (Conjuntos de bienes que son preferibles a otros segun las diferentes condiciones).***

# %% [markdown]
# - ***Curvas de indiferencia de la Función de Utilidad***

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definimos la función de utilidad y su inversa para los conjuntos de nivel
def u(x, y):
    return np.sqrt(x * y)

def preimage(u0, x):
    return u0**2 / x

# Valores de utilidad para los contornos
u_levels = [5, 10, 15, 20, 25]

# Rango de valores para x
x = np.linspace(0.1, 10, 400)  # evitamos x=0 para evitar división por cero

# Creamos la figura
plt.figure(figsize=(10, 6))

# Dibujamos los conjuntos de nivel
for u0 in u_levels:
    y = preimage(u0, x)
    plt.plot(x, y, label=f'u0 = {u0}')

# Etiquetas y título
plt.xlabel('Bien X')
plt.ylabel('Bien Y')
plt.title('Conjuntos de Nivel de la Función de Utilidad')
plt.legend()

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# ## 💻 ***Función Sobreyectiva, Biyectiva, Inyectiva, Inversa y Compuesta***

# %% [markdown]
# #### ✔️  1. ***Definición de una Función***
# Una función $( f )$ que va del conjunto $( A )$ al conjunto $( B )$ se denota como:
# $[ f: A \to B ]$
# y asigna a cada elemento $( x \in A )$ un elemento $( f(x) \in B )$.

# %% [markdown]
# #### ✔️ ***2. Imágenes de una Función***
# - La imagen de $( A )$ bajo $( f )$, denotada como $( f(A) )$, es el conjunto de todos los elementos de $( B )$ que son imágenes de los elementos de $( A ):
#   [ f(A) = \{ f(x) \in B : x \in A \} ]$

# %% [markdown]
# #### ✔️***3. Sobreyectividad***
# - Una función $( f )$ es **sobreyectiva** si su imagen cubre todo el conjunto $( B ):
#   [ f(A) = B ]$
#
#   Esto significa que para cada $( y \in B )$, existe al menos un $( x \in A )$ tal que:
#
#   $[ f(x) = y ]$

# %% [markdown]
#
# #### ✔️ ***4. Inyectividad***
# - Una función $( f )$ es **inyectiva** si asigna elementos distintos de $( A )$ a elementos distintos de $( B )$. Formalmente, $( f )$ es inyectiva si:
#
#   $[ \forall x, x' \in A, \, x \neq x' \implies f(x) \neq f(x') ]$

# %% [markdown]
# #### ✔️ ***5. Biyectividad***
# - Una función $( f )$ es **biyectiva** si es a la vez inyectiva y sobreyectiva. Esto implica que $( f )$ asigna una correspondencia uno a uno entre los elementos de $( A )$ y los elementos de $( B )$. En términos formales:
#   $[ f \text{ es biyectiva} \iff f \text{ es inyectiva} \, \land \, f \text{ es sobreyectiva} ]$

# %% [markdown]
# #### ✔️ ***6. Función Inversa***
# - Si $( f )$ es biyectiva, entonces tiene una función inversa $( f^{-1} )$ que va de $( B )$ a $( A )$.
#
#   La función inversa $( g )$ cumple con:
#   $[ g: B \to A ]$
#   $[ g(y) = x \quad \text{tal que} \quad f(x) = y ]$
#
#   La función inversa $( g )$ se denota como $( f^{-1} )$.
#
#    Las propiedades que deben cumplirse son:
#   $[ \forall x \in A, \, g(f(x)) = x ]$
#   $[ \forall y \in B, \, f(g(y)) = y ]$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Crear una figura con tres subgráficos
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Datos para las gráficas
x = np.linspace(-10, 10, 400)

# Inyectiva: f(x) = 2x + 1
f_inyectiva = 2 * x + 1
axs[0].plot(x, f_inyectiva, label='f(x) = 2x + 1')
axs[0].set_title('Función Inyectiva')
axs[0].set_xlabel('x')
axs[0].set_ylabel('f(x)')
axs[0].axhline(0, color='black', linewidth=0.5)
axs[0].axvline(0, color='black', linewidth=0.5)
axs[0].legend()
axs[0].grid(True)

# Sobreyectiva: f(x) = tanh(x)
f_sobreyectiva = np.tanh(x)
axs[1].plot(x, f_sobreyectiva, label='f(x) = tanh(x)', color='orange')
axs[1].set_title('Función Sobreyectiva')
axs[1].set_xlabel('x')
axs[1].set_ylabel('f(x)')
axs[1].axhline(0, color='black', linewidth=0.5)
axs[1].axvline(0, color='black', linewidth=0.5)
axs[1].legend()
axs[1].grid(True)

# Biyectiva: f(x) = x^3
f_biyectiva = x**3
axs[2].plot(x, f_biyectiva, label='f(x) = x^3', color='green')
axs[2].set_title('Función Biyectiva')
axs[2].set_xlabel('x')
axs[2].set_ylabel('f(x)')
axs[2].axhline(0, color='black', linewidth=0.5)
axs[2].axvline(0, color='black', linewidth=0.5)
axs[2].legend()
axs[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ©️ ***Explicación sobre Funciones Compuestas***

# %% [markdown]
# 1. 🔑 **Definiciones Iniciales**:
#   - *Se definen tres conjuntos:* $( E )$, $( F )$ y $( G )$.
#   - Se definen dos funciones: \( f \) y \( g \).
#     - $( f: E \rightarrow F \), donde \( f(x) = f(x) )$.
#
#     - $( g: F \rightarrow G ), donde ( g(y) = g(y) )$.

# %% [markdown]
# 2. 🔑 **Función Compuesta**:
#     - La función compuesta
#   $( g \circ f )$ se define como:
# $[
# (g \circ f)(x) = g(f(x))
# ]$
# Esta composición toma un elemento $( x )$ de $( E )$, aplica la función $( f )$ para obtener $( f(x) )$ en $( F )$, y luego aplica la función $( g )$ a $( f(x) )$ para obtener $( g(f(x)) )$ en $( G )$.

# %% [markdown]
# 3. 🔑 **Ejemplo de Función Compuesta**:
#   - Se define una función $( h(x) \):
#       \[
#       h(x) = \sqrt{x^2 + 1}
#       ]$

# %% [markdown]
# 4. 🔑 **Definición de Funciones**:
#
#     - Se define la función $( f )$ de los reales a un intervalo:
#       $[
#       f: \mathbb{R} \rightarrow [1, +\infty[
#       ]$
#       $[
#       f(x) = x^2 + 1
#       ]$
#     - Se define la función $( g )$ del intervalo $( [1, +\infty[ )$ a los reales positivos:
#       $[
#       g: [1, +\infty[ \rightarrow \mathbb{R}^+
#       ]$
#       $[
#       g(y) = \sqrt{y}
#       ]$

# %% [markdown]
# 5. 🔑 **Composición de $( g )$ y $( f )$**:
#
#     - La composición $( g \circ f )$ se define como:
#       $[
#       g \circ f: \mathbb{R} \rightarrow \mathbb{R}^+
#       ]$
#       $[
#       (g \circ f)(x) = g(f(x)) = g(x^2 + 1) = \sqrt{x^2 + 1}
#       \]rt{x^2 + 1}

# %% [markdown]
# 6. 🔑 **Conclusión**:
#     - Se demuestra que $( h(x) )$ es igual a la composición $( g \circ f )$ para todos los $( x )$ en los reales:
#       $[
#       h(x) = g \circ f(x) \quad \forall x \in \mathbb{R} \Leftrightarrow h = g \circ f
#       ]$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definición de las funciones
def f(x):
    return x**2 + 1

def g(y):
    return np.sqrt(y)

def h(x):
    return g(f(x))

# Valores de x para graficar
x = np.linspace(-10, 10, 400)

# Graficar las funciones
plt.figure(figsize=(10, 6))

plt.plot(x, f(x), label='$f(x) = x^2 + 1$', color='blue')
plt.plot(x, g(f(x)), label='$g(f(x)) = \sqrt{x^2 + 1}$', color='red')
plt.plot(x, h(x), label='$h(x) = g(f(x)) = \sqrt{x^2 + 1}$', linestyle='dashed', color='green')

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(True)
plt.legend()
plt.title('Visualización de la Función Compuesta $h(x) = g(f(x))$')

plt.show()

# %% [markdown]
# ##  🌟 ***Conclusión General sobre Funciones y su Aplicación***
#
# Las funciones inyectivas, sobreyectivas y biyectivas 🎯 juegan un papel crucial en la teoría de funciones, proporcionando una base sólida para comprender cómo los elementos de diferentes conjuntos están relacionados entre sí. Estas propiedades son fundamentales para asegurar que cada elemento de un conjunto tiene una correspondencia clara y única en otro conjunto, lo cual es esencial en muchas aplicaciones matemáticas y científicas 🧠📐.
#
# En el ámbito de la economía 📊, estas funciones se aplican para modelar relaciones entre variables económicas, como la utilidad y el consumo, permitiendo un análisis preciso de cómo los cambios en una variable afectan a otra. Las funciones compuestas 🔄, que combinan varias funciones en una, son especialmente útiles para describir procesos económicos complejos donde múltiples etapas de transformación o cambio están involucradas.
#
# Mediante la composición de funciones, podemos simplificar y resolver problemas que implican varias transformaciones sucesivas, ofreciendo una herramienta poderosa para la modelización y el análisis económico 💡💼. La visualización de estas funciones y sus composiciones no solo facilita la comprensión de sus propiedades teóricas, sino que también proporciona una representación clara y accesible de sus aplicaciones prácticas en economía y otros campos 📈.
